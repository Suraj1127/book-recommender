# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ls
# Out:
# exploration.ipynb

# %%
books = pd.read_csv('../data/raw/books.csv')
ratings = pd.read_csv('../data/raw/ratings.csv')

# %%
books.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# ...

# %%
books['id'].describe()
# Out:
# count    10000.00000
# mean      5000.50000
# std       2886.89568
# min          1.00000
# 25%       2500.75000
# 50%       5000.50000
# 75%       7500.25000
# max      10000.00000
# Name: id, dtype: float64

# %%
books['book_id'].describe()
# Out:
# count    1.000000e+04
# mean     5.264697e+06
# std      7.575462e+06
# min      1.000000e+00
# 25%      4.627575e+04
# 50%      3.949655e+05
# 75%      9.382225e+06
# max      3.328864e+07
# Name: book_id, dtype: float64

# %%
books[books['title'] == 'Siddhartha']
# Out:
#       id  book_id  best_book_id  work_id  books_count       isbn  \
# 179  180    52036         52036  4840290          972  553208845
#
#            isbn13                      authors  original_publication_year  \
# 179  9.780553e+12  Hermann Hesse, Hilda Rosner                     1922.0
#
#     original_title                        ...                          \
# 179     Siddhartha                        ...
#
#     ratings_count work_ratings_count  work_text_reviews_count  ratings_1  \
# 179        372099             418653                    11518      10229
#
#      ratings_2  ratings_3  ratings_4  ratings_5  \
# 179      25529      83698     138837     160360
#
#                                              image_url  \
# 179  https://images.gr-assets.com/books/1428715580m...
#
#                                        small_image_url
# 179  https://images.gr-assets.com/books/1428715580s...
#
# [1 rows x 23 columns]

# %%
import json

# %%
d = books['title'].to_dict()

# %%
ls
# Out:
# collaborative_filtering.py  feature_generator.py  recommender.py
# data/                       features/             user_ratings.json
# exploration.ipynb           __pycache__/

# %%
with open('books_map.json', 'w') as f:
    json.dump(d, f)

# %%
books[['id', 'title']].T.to_dict()
# Out:
# {0: {'id': 1, 'title': 'The Hunger Games (The Hunger Games, #1)'},
#  1: {'id': 2,
#   'title': "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)"},
#  2: {'id': 3, 'title': 'Twilight (Twilight, #1)'},
#  3: {'id': 4, 'title': 'To Kill a Mockingbird'},
#  4: {'id': 5, 'title': 'The Great Gatsby'},
#  5: {'id': 6, 'title': 'The Fault in Our Stars'},
#  6: {'id': 7, 'title': 'The Hobbit'},
#  7: {'id': 8, 'title': 'The Catcher in the Rye'},
#  8: {'id': 9, 'title': 'Angels & Demons  (Robert Langdon, #1)'},
#  9: {'id': 10, 'title': 'Pride and Prejudice'},
#  10: {'id': 11, 'title': 'The Kite Runner'},
#  11: {'id': 12, 'title': 'Divergent (Divergent, #1)'},
#  12: {'id': 13, 'title': '1984'},
#  13: {'id': 14, 'title': 'Animal Farm'},
#  14: {'id': 15, 'title': 'The Diary of a Young Girl'},
#  15: {'id': 16, 'title': 'The Girl with the Dragon Tattoo (Millennium, #1)'},
#  16: {'id': 17, 'title': 'Catching Fire (The Hunger Games, #2)'},
#  17: {'id': 18,
# ...

# %%
books.sample(frac=1)
# Out:
#         id   book_id  best_book_id   work_id  books_count        isbn  \
# 5494  5495     10669         10669     13308           17   375758259
# 4989  4990    285011        285011    276514           23  1414310560
# 737    738      9822          9822    839692           73   689862202
# 5557  5558     32434         32434    944284           50   425210758
# 2594  2595    136167        136167   1030360           81   440060672
# 3267  3268   1128178      32722510   2915978           52   393061728
# 6983  6984   6617185       6617185   6811292           38  1568584253
# 4213  4214    785453        785453    771451           38   440418518
# 2282  2283   7778981       7778981  10695325           54   312656262
# 2002  2003  23995231      23995231  43446210           42   345534182
# 2486  2487     68494         68494   3221410           63   345459407
# 7726  7727     73184         73184    996684           26  1573225681
# ...

# %%
ratings.shape
# Out:
# (981756, 3)

# %%
ratings[ratings[['book_id', 'user_id']].duplicated(keep=False)]
# Out:
#         book_id  user_id  rating
# 1170         12    40251       4
# 1171         12    40251       4
# 2473         25    32635       5
# 2474         25    32635       5
# 2717         28     9011       2
# 2718         28     9011       1
# 2946         30    24582       4
# 2947         30    24582       3
# 2958         30    31760       4
# 2959         30    31760       4
# 3019         31     8669       5
# 3020         31     8669       5
# 3333         34    26097       1
# 3334         34    26097       1
# 3775         38    31198       4
# 3776         38    31198       5
# 4639         47    19191       5
# 4640         47    19191       5
# 4771         48    37834       4
# 4772         48    37834       4
# 5717         58     8579       3
# 5718         58     8579       3
# 6901         70      725       5
# 6902         70      725       4
# 7908         80     5379       5
# 7909         80     5379       5
# 8281         83    33864       2
# ...
